# %% [markdown]
# # 决策树回归

# %%
# %matplotlib inline
from sklearn import tree
import pandas as pd
import numpy as np

# %%
# 加载数据
data = pd.read_csv('data/Advertising.csv',index_col=0) # index_col索引列
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
# conventional way to import seaborn
import seaborn as sns

# allow plots to appear within the notebook
# %matplotlib inline

sns.pairplot(data, x_vars=['TV','Radio','Newspaper'], y_vars='Sales', height=7, aspect=0.7, kind='reg')

# %%
# create a Python list of feature names
feature_cols = ['TV', 'Radio', 'Newspaper']

# use the list to select a subset of the original DataFrame
X = data[feature_cols]

y = data['Sales']

# %%
# 拆分数据集
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# 建模
clf = tree.DecisionTreeRegressor()
clf = clf.fit(X_train, y_train)
clf.predict(X_test)
# Out:
# array([23.7, 16.6,  9.6, 13.4, 17. , 24.4, 17.1, 14.4, 10.9, 17. , 14.9,
#        11.3, 17.4, 15.3, 13.4, 18.5, 13.2, 12.7,  4.8, 18. , 10.6, 12.6,
#         7. , 12.4, 13.2, 14.7, 10.1, 19.8, 18. , 15.5, 21.7, 11.7, 18. ,
#        12.6, 20.2, 14.9, 12. , 11.2, 21.7,  6.9,  5.9,  9.6,  6.6, 19.4,
#         6.6, 15.6, 13.6, 21.8, 21.7, 20.1])

# %%
# 模型评分
from sklearn import metrics #指标

# make predictions on the testing set
y_pred = clf.predict(X_test)

# compute the RMSE of our predictions
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))


print(clf.score(X_test, y_test))
# Out:
# 1.0609429767899876
# 0.9518629500211178
